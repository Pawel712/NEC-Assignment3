# %%
import numpy as np
from sklearn import datasets
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import pandas as pd

# %%
with open('../Datasets/A3-dataset1Modified.csv', 'r') as file:
   dataset = pd.read_csv('../Datasets/A3-dataset1Modified.csv', sep=',')

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Create a t-SNE instance and fit_transform the data
X_tsne = tsne.fit_transform(X)
tsne = TSNE(n_components=2, perplexity=5, learning_rate=2, n_iter=1000, verbose=1)

#colored scatter plot of the first two principal components
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.title('t-SNE - Scatter Plot Dataset 1')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(handles=scatter.legend_elements()[0], labels=set(y), title='Classes')
plt.show(block=True)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 360 samples in 0.004s...
# [t-SNE] Computed neighbors for 360 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 360 / 360
# [t-SNE] Mean sigma: 0.301878
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.150536
# [t-SNE] KL divergence after 1000 iterations: 0.627968

# %%
with open('../Datasets/A3-dryBeansModified.csv', 'r') as file:
    dataset = pd.read_csv('../Datasets/A3-dryBeansModified.csv', sep=',')

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Create a t-SNE instance and fit_transform the data
X_tsne = tsne.fit_transform(X)
tsne = TSNE(n_components=2, perplexity=30, learning_rate=100, n_iter=1000, verbose=1)

#colored scatter plot of the first two principal components
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.title('t-SNE - Scatter Plot Dataset 2')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(handles=scatter.legend_elements()[0], labels=set(y), title='Classes')
plt.show(block=True)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2500 samples in 0.002s...
# [t-SNE] Computed neighbors for 2500 samples in 0.129s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2500
# [t-SNE] Computed conditional probabilities for sample 2000 / 2500
# [t-SNE] Computed conditional probabilities for sample 2500 / 2500
# [t-SNE] Mean sigma: 0.521564
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.201378
# [t-SNE] KL divergence after 1000 iterations: 1.058838
